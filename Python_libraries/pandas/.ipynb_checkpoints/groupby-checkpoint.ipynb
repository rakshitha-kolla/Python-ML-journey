# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("matches.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ## groupby()

# %%
teams=df.groupby("team1")
teams

# %%
teams.size().sort_values(ascending=False)
# Out:
# team1
# Mumbai Indians                 82
# Chennai Super Kings            77
# Kings XI Punjab                77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# dtype: int64

# %%
teams.first()
# Out:
#                               id  season        city        date  \
# team1
# Chennai Super Kings           61    2008  Chandigarh  2008-04-19
# Deccan Chargers               64    2008     Kolkata  2008-04-20
# Delhi Daredevils               9    2017        Pune  2017-04-11
# Gujarat Lions                  3    2017      Rajkot  2017-04-07
# Kings XI Punjab               11    2017     Kolkata  2017-04-13
# Kochi Tuskers Kerala         237    2011       Kochi  2011-04-09
# Kolkata Knight Riders          7    2017      Mumbai  2017-04-09
# Mumbai Indians                 2    2017        Pune  2017-04-06
# Pune Warriors                250    2011      Mumbai  2011-04-17
# Rajasthan Royals              62    2008       Delhi  2008-04-19
# Rising Pune Supergiant         4    2017      Indore  2017-04-08
# Rising Pune Supergiants      582    2016      Rajkot  2016-04-14
# Royal Challengers Bangalore    5    2017   Bangalore  2017-04-08
# ...

# %%
teams.last()
# Out:
#                               id  season           city        date  \
# team1
# Chennai Super Kings          565    2015         Raipur  2015-05-12
# Deccan Chargers              376    2012      Hyderabad  2012-05-20
# Delhi Daredevils             632    2016         Raipur  2016-05-22
# Gujarat Lions                635    2016          Delhi  2016-05-27
# Kings XI Punjab              629    2016  Visakhapatnam  2016-05-21
# Kochi Tuskers Kerala         290    2011         Indore  2011-05-13
# Kolkata Knight Riders        631    2016        Kolkata  2016-05-22
# Mumbai Indians               630    2016         Kanpur  2016-05-21
# Pune Warriors                451    2013           Pune  2013-05-19
# Rajasthan Royals             570    2015         Mumbai  2015-05-16
# Rising Pune Supergiant        56    2017         Mumbai  2017-05-16
# Rising Pune Supergiants      621    2016        Kolkata  2016-05-14
# Royal Challengers Bangalore  626    2016      Bangalore  2016-05-18
# ...

# %%
len(teams)
# Out:
# 14

# %%
teams.groups
# Out:
# {'Chennai Super Kings': [60, 66, 73, 78, 82, 84, 90, 95, 116, 121, 130, 136, 140, 143, 148, 158, 165, 168, 172, 181, 193, 205, 210, 215, 223, 231, 233, 234, 242, 247, 251, 261, 271, 280, 284, 288, 296, 301, 306, 307, 312, 317, 323, 331, 346, 351, 354, 370, 378, 379, 380, 403, 417, 421, 424, 434, 441, 445, 453, 459, 464, 466, 477, 498, 503, 506, 518, 520, 526, 532, 537, 541, 546, 553, 558, 562, 564], 'Deccan Chargers': [63, 65, 67, 76, 79, 88, 107, 113, 123, 127, 135, 139, 146, 150, 154, 173, 178, 185, 188, 194, 219, 228, 232, 235, 244, 248, 252, 264, 278, 285, 291, 299, 315, 322, 327, 330, 336, 340, 345, 347, 355, 365, 375], 'Delhi Daredevils': [8, 14, 17, 30, 34, 50, 72, 75, 86, 92, 97, 99, 124, 132, 157, 160, 164, 166, 171, 184, 196, 199, 202, 208, 217, 237, 240, 258, 262, 268, 273, 300, 341, 344, 356, 363, 381, 393, 400, 418, 427, 432, 442, 458, 479, 482, 484, 488, 501, 511, 522, 530, 534, 538, 542, 555, 570, 577, 592, 601, 608, 624, 631], 'Gujarat Lions': [2, 5, 15, 33, 37, 40, 4
# ...

# %%
teams.get_group("Royal Challengers Bangalore")
# Out:
#       id  season        city        date                        team1  \
# 4      5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 7      8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 11    12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 19    20    2017      Rajkot  2017-04-18  Royal Challengers Bangalore
# 29    30    2017   Bangalore  2017-04-27  Royal Challengers Bangalore
# ..   ...     ...         ...         ...                          ...
# 605  606    2016   Bangalore  2016-05-02  Royal Challengers Bangalore
# 614  615    2016  Chandigarh  2016-05-09  Royal Challengers Bangalore
# 616  617    2016   Bangalore  2016-05-11  Royal Challengers Bangalore
# 619  620    2016   Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016   Bangalore  2016-05-18  Royal Challengers Bangalore
#
#                      team2                  toss_winner toss_decision  result  \
# ...

# %%
teams.sum()
# Out:
#                                 id  season  \
# team1
# Chennai Super Kings          24170  154885
# Deccan Chargers               9425   86437
# Delhi Daredevils             19979  126788
# Gujarat Lions                 3914   28232
# Kings XI Punjab              24966  154976
# Kochi Tuskers Kerala          1848   14077
# Kolkata Knight Riders        20139  136823
# Mumbai Indians               27142  165023
# Pune Warriors                 6900   40241
# Rajasthan Royals             16962  108623
# Rising Pune Supergiant         223   16136
# Rising Pune Supergiants       4202   14112
# Royal Challengers Bangalore  23257  140902
# Sunrisers Hyderabad          19439   92689
#
#                                                                           city  \
# team1
# Chennai Super Kings          ChandigarhChennaiBangaloreChennaiJaipurChennai...
# Deccan Chargers              KolkataHyderabadHyderabadHyderabadHyderabadJai...
# ...

# %%
teams["win_by_runs"].sum()
# Out:
# team1
# Chennai Super Kings            1594
# Deccan Chargers                 421
# Delhi Daredevils                596
# Gujarat Lions                     1
# Kings XI Punjab                 867
# Kochi Tuskers Kerala             23
# Kolkata Knight Riders           879
# Mumbai Indians                 1532
# Pune Warriors                   139
# Rajasthan Royals                821
# Rising Pune Supergiant          123
# Rising Pune Supergiants           0
# Royal Challengers Bangalore    1196
# Sunrisers Hyderabad             510
# Name: win_by_runs, dtype: int64

# %%
delivery=pd.read_csv("deliveries.csv")

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %% [markdown]
# ## top 5 batsman who scored high run in all seasons

# %%
batsman=delivery.groupby("batsman")

# %%
batsman.size()
# Out:
# batsman
# A Ashish Reddy     196
# A Chandila           7
# A Chopra            75
# A Choudhary         20
# A Flintoff          57
#                   ...
# YV Takawale        183
# Yashpal Singh       67
# Younis Khan          7
# Yuvraj Singh      2050
# Z Khan             141
# Length: 461, dtype: int64

# %%
batsman.first()
# Out:
#                 match_id  inning                 batting_team  \
# batsman
# A Ashish Reddy       346       1              Deccan Chargers
# A Chandila           373       1             Rajasthan Royals
# A Chopra              88       1        Kolkata Knight Riders
# A Choudhary            1       2  Royal Challengers Bangalore
# A Flintoff           118       2          Chennai Super Kings
# ...                  ...     ...                          ...
# YV Takawale           82       1               Mumbai Indians
# Yashpal Singh        126       2        Kolkata Knight Riders
# Younis Khan           97       2             Rajasthan Royals
# Yuvraj Singh           1       1          Sunrisers Hyderabad
# Z Khan                 5       2             Delhi Daredevils
#
#                                bowling_team  over  ball    non_striker  \
# batsman
# A Ashish Reddy               Mumbai Indians    14     1      JP Duminy
# ...

# %%
batsman.last()
# Out:
#                 match_id  inning                 batting_team  \
# batsman
# A Ashish Reddy       603       1          Sunrisers Hyderabad
# A Chandila           407       1             Rajasthan Royals
# A Chopra             121       1        Kolkata Knight Riders
# A Choudhary           42       2  Royal Challengers Bangalore
# A Flintoff           125       2          Chennai Super Kings
# ...                  ...     ...                          ...
# YV Takawale          510       1  Royal Challengers Bangalore
# Yashpal Singh        168       2        Kolkata Knight Riders
# Younis Khan           97       2             Rajasthan Royals
# Yuvraj Singh         636       1          Sunrisers Hyderabad
# Z Khan               623       2             Delhi Daredevils
#
#                                bowling_team  over  ball   non_striker  \
# batsman
# A Ashish Reddy  Royal Challengers Bangalore    20     6  MC Henriques
# ...

# %%
batsman.sum("batsman_runs").sort_values("batsman_runs",ascending=False).head()
# Out:
#            match_id  inning   over   ball  is_super_over  wide_runs  bye_runs  \
# batsman
# SK Raina    1079285    4748  32746  12256              3        124         0
# V Kohli     1304291    5112  33426  12284              2        110         5
# RG Sharma   1081920    4822  36662  11601              0         66         2
# G Gambhir   1072760    5510  23650  12313              0        151        10
# DA Warner   1085379    4258  21153  10188              1        108        23
#
#            legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# batsman
# SK Raina            57           16             0          4548         197
# V Kohli             39           11             0          4423         165
# RG Sharma           48           11             0          4207         127
# G Gambhir           85           10             0          4132         256
# DA Warner           52           16             0          4014         199
#
# ...

# %%
batsman.get_group("V Kohli")
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
batsman["batsman_runs"].sum().sort_values(ascending=False)
# Out:
# batsman
# SK Raina        4548
# V Kohli         4423
# RG Sharma       4207
# G Gambhir       4132
# DA Warner       4014
#                 ...
# Abdur Razzak       0
# S Kaushik          0
# S Ladda            0
# U Kaul             0
# RR Bhatkal         0
# Name: batsman_runs, Length: 461, dtype: int64

# %% [markdown]
# ## top five heighest fours scored by batsman

# %%
b=delivery["batsman_runs"]==4

# %%
b
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459     True
# Name: batsman_runs, Length: 150460, dtype: bool

# %%
data=delivery[b].groupby("batsman")

# %%
data.first()
# Out:
#                 match_id  inning                 batting_team  \
# batsman
# A Ashish Reddy       359       2              Deccan Chargers
# A Chopra              92       1        Kolkata Knight Riders
# A Choudhary           30       1  Royal Challengers Bangalore
# A Flintoff           118       2          Chennai Super Kings
# A Kumble             101       2  Royal Challengers Bangalore
# ...                  ...     ...                          ...
# YK Pathan             14       1        Kolkata Knight Riders
# YV Takawale           82       1               Mumbai Indians
# Yashpal Singh        126       2        Kolkata Knight Riders
# Yuvraj Singh           1       1          Sunrisers Hyderabad
# Z Khan                70       1  Royal Challengers Bangalore
#
#                                bowling_team  over  ball    non_striker  \
# batsman
# A Ashish Reddy              Kings XI Punjab    18     4       J Theron
# ...

# %%
data["batsman_runs"].sum().sort_values(ascending=False)
# Out:
# batsman
# G Gambhir         1936
# SK Raina          1608
# DA Warner         1604
# S Dhawan          1604
# V Kohli           1536
#                   ...
# S Gopal              4
# DE Bollinger         4
# Sandeep Sharma       4
# Shivam Sharma        4
# KAJ Roach            4
# Name: batsman_runs, Length: 368, dtype: int64

# %%
data["batsman_runs"].count().sort_values(ascending=False)
# Out:
# batsman
# G Gambhir         484
# SK Raina          402
# DA Warner         401
# S Dhawan          401
# V Kohli           384
#                  ...
# S Gopal             1
# DE Bollinger        1
# Sandeep Sharma      1
# Shivam Sharma       1
# KAJ Roach           1
# Name: batsman_runs, Length: 368, dtype: int64

# %%
data["batsman_runs"].count()
# Out:
# batsman
# A Ashish Reddy     16
# A Chopra            7
# A Choudhary         1
# A Flintoff          5
# A Kumble            3
#                  ...
# YK Pathan         240
# YV Takawale        26
# Yashpal Singh       5
# Yuvraj Singh      205
# Z Khan             11
# Name: batsman_runs, Length: 368, dtype: int64

# %%
data.get_group("CH Gayle").count()
# Out:
# match_id            297
# inning              297
# batting_team        297
# bowling_team        297
# over                297
# ball                297
# batsman             297
# non_striker         297
# bowler              297
# is_super_over       297
# wide_runs           297
# bye_runs            297
# legbye_runs         297
# noball_runs         297
# penalty_runs        297
# batsman_runs        297
# extra_runs          297
# total_runs          297
# player_dismissed      0
# dismissal_kind        0
# fielder               0
# dtype: int64

# %%
## find hieght score of virat kohli against which team

# %%
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
data=delivery.groupby("batsman")

# %%
data2=data.get_group("V Kohli")

# %%
data2
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
data3=data2.groupby("bowling_team")

# %%
data3.first()
# Out:
#                          match_id  inning                 batting_team  over  \
# bowling_team
# Chennai Super Kings            74       2  Royal Challengers Bangalore    16
# Deccan Chargers                80       2  Royal Challengers Bangalore    16
# Delhi Daredevils               55       1  Royal Challengers Bangalore     5
# Gujarat Lions                  20       1  Royal Challengers Bangalore     1
# Kings XI Punjab                42       2  Royal Challengers Bangalore     1
# Kochi Tuskers Kerala          237       2  Royal Challengers Bangalore     2
# Kolkata Knight Riders          27       2  Royal Challengers Bangalore     1
# Mumbai Indians                 12       1  Royal Challengers Bangalore     1
# Pune Warriors                 268       1  Royal Challengers Bangalore     7
# Rajasthan Royals               70       1  Royal Challengers Bangalore     7
# Rising Pune Supergiant         17       2  Royal Challengers Bangalore     1
# ...

# %%
data3["batsman_runs"].sum().sort_values(ascending=False)
# Out:
# bowling_team
# Chennai Super Kings        706
# Delhi Daredevils           661
# Kings XI Punjab            483
# Mumbai Indians             447
# Sunrisers Hyderabad        439
# Kolkata Knight Riders      391
# Deccan Chargers            306
# Gujarat Lions              283
# Rajasthan Royals           258
# Rising Pune Supergiants    188
# Pune Warriors              128
# Rising Pune Supergiant      83
# Kochi Tuskers Kerala        50
# Name: batsman_runs, dtype: int64

# %%
def runs_scored(batsman_name):
    vk=delivery[delivery["batsman"]==batsman_name]
    return vk.groupby("bowling_team")["batsman_runs"].sum().sort_values(ascending=False).index[0]

# %%
runs_scored("V Kohli")
# Out:
# 'Chennai Super Kings'
