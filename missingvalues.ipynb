# %%
import pandas as pd
import numpy as np

# %%
id=pd.Series(["R200351","R200340","R200341","R200303","R200459","R200333"])
name=pd.Series(["RAKSHI","sri","pandu","abhi","gayathri","meghana"])
Class=[]
for i in range(0,6,1):
    Class.append("e2")
ph_no=pd.Series([8520992072,np.nan,8008862282,630541789,np.nan,np.nan])
address=pd.Series([np.nan,"Ananthapur",np.nan,np.nan,"Kurnool","Nellore"])
df=pd.DataFrame({"ID":id,"NAME":name,"CLASS":Class,"PHONE NO":ph_no,"PLACE":address})
df
# Out:
#         ID      NAME CLASS      PHONE NO       PLACE
# 0  R200351    RAKSHI    e2  8.520992e+09         NaN
# 1  R200340       sri    e2           NaN  Ananthapur
# 2  R200341     pandu    e2  8.008862e+09         NaN
# 3  R200303      abhi    e2  6.305418e+08         NaN
# 4  R200459  gayathri    e2           NaN     Kurnool
# 5  R200333   meghana    e2           NaN     Nellore

# %%
#checking if each and every field is null
df.isnull()
df.count()
# Out:
# ID          6
# NAME        6
# CLASS       6
# PHONE NO    3
# PLACE       3
# dtype: int64

# %%
#checking if the columns have null values or not
df.isnull().any()
# Out:
# ID          False
# NAME        False
# CLASS       False
# PHONE NO     True
# PLACE        True
# dtype: bool

# %%
#checking if the columns have null values using column name
print(df["ID"].isnull().any())
print(df["PLACE"].isnull().any())
# Out:
# False
# True

# %%
#removing the rows that have null values
a=df.dropna()
a
# Out:
# Empty DataFrame
# Columns: [ID, NAME, CLASS, PHONE NO, PLACE]
# Index: []

# %%
#removing the columns that have null values
df.dropna(axis=1)
# Out:
#         ID      NAME CLASS
# 0  R200351    RAKSHI    e2
# 1  R200340       sri    e2
# 2  R200341     pandu    e2
# 3  R200303      abhi    e2
# 4  R200459  gayathri    e2
# 5  R200333   meghana    e2

# %%
df.drop("ID",axis=1)
# Out:
#        NAME CLASS      PHONE NO       PLACE
# 0    RAKSHI    e2  8.520992e+09         NaN
# 1       sri    e2           NaN  Ananthapur
# 2     pandu    e2  8.008862e+09         NaN
# 3      abhi    e2  6.305418e+08         NaN
# 4  gayathri    e2           NaN     Kurnool
# 5   meghana    e2           NaN     Nellore

# %%
df.drop(0,axis=0)
# Out:
#         ID      NAME CLASS      PHONE NO       PLACE
# 1  R200340       sri    e2           NaN  Ananthapur
# 2  R200341     pandu    e2  8.008862e+09         NaN
# 3  R200303      abhi    e2  6.305418e+08         NaN
# 4  R200459  gayathri    e2           NaN     Kurnool
# 5  R200333   meghana    e2           NaN     Nellore

# %%
df
# Out:
#         ID      NAME CLASS      PHONE NO       PLACE
# 0  R200351    RAKSHI    e2  8.520992e+09         NaN
# 1  R200340       sri    e2           NaN  Ananthapur
# 2  R200341     pandu    e2  8.008862e+09         NaN
# 3  R200303      abhi    e2  6.305418e+08         NaN
# 4  R200459  gayathri    e2           NaN     Kurnool
# 5  R200333   meghana    e2           NaN     Nellore

# %%
#filling the null values with -
df.fillna("0")
# Out:
#         ID      NAME CLASS      PHONE NO       PLACE
# 0  R200351    RAKSHI    e2  8520992072.0           0
# 1  R200383   Rajitha    e2             0  Ananthapur
# 2  R200362    Cherry    e2  8008862282.0           0
# 3  R200303      abhi    e2  6305417896.0           0
# 4  R200459  gayathri    e2             0     Kurnool
# 5  R200333   meghana    e2             0  Uravakonda

# %%
#filling the null values with earlier row values
df.ffill()
# Out:
#         ID      NAME CLASS      PHONE NO       PLACE
# 0  R200351    RAKSHI    e2  8.520992e+09         NaN
# 1  R200340       sri    e2  8.520992e+09  Ananthapur
# 2  R200341     pandu    e2  8.008862e+09  Ananthapur
# 3  R200303      abhi    e2  6.305418e+08  Ananthapur
# 4  R200459  gayathri    e2  6.305418e+08     Kurnool
# 5  R200333   meghana    e2  6.305418e+08     Nellore

# %%
#inputing missing values using median in phone no and a string instead of a place 
a=df["PHONE NO"].median()
df.fillna({"PHONE NO":a,"PLACE":"DMM"})
# Out:
#         ID      NAME CLASS      PHONE NO       PLACE
# 0  R200351    RAKSHI    e2  8.520992e+09         DMM
# 1  R200340       sri    e2  8.008862e+09  Ananthapur
# 2  R200341     pandu    e2  8.008862e+09         DMM
# 3  R200303      abhi    e2  6.305418e+08         DMM
# 4  R200459  gayathri    e2  8.008862e+09     Kurnool
# 5  R200333   meghana    e2  8.008862e+09     Nellore
