# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in ./notebookenv/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in ./notebookenv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in ./notebookenv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
df=pd.DataFrame({"height":height,"weight":weight})
df
# Out:
#    height  weight
# 0   121.9    19.7
# 1   124.5    21.3
# 2   129.5    23.5
# 3   134.6    25.9
# 4   139.7    28.5
# 5   147.3    32.1
# 6   152.4    35.7
# 7   157.5    39.6
# 8   162.6    43.2

# %%
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
df=pd.DataFrame({"height":height,"weight":weight})
df
plt.plot(weight,height,color="green",marker=">",linestyle="dashdot",linewidth=2,markersize=10)
plt.xlabel("Weight in kg")
plt.ylabel("Height in cm")
plt.title("Average weight with respect to average height")
plt.grid(True);
plt.show()

# %%
plt.bar(df.height,df.weight)
plt.show()

# %%
df.plot(kind="bar")
plt.show()

# %%
import pandas as pd
df=pd.DataFrame({0:[1,2,3,4],1:[4,5,6,7]})
plt.plot(df[0],df[1],marker="*")
plt.show()

# %%
#sctter\
import pandas as pd
df=pd.DataFrame({"day":[1,2,3,4],"date":[4,5,6,7]})
df.plot.scatter("day","date",color="red",marker="*")
# Out:
# <Axes: xlabel='day', ylabel='date'>

# %%
x=[4,5,3]
y=[1,2,3]
plt.scatter(x,y,color="red",marker="*")
plt.title("hello")
plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv(r"/home/rguktrkvalley/Desktop/melasales.csv")
df
# Out:
#    week1  week2  week3        day
# 0   5000   4000   4000     monday
# 1   5900   3000   5800    tuesday
# 2   6500   5000   3500  wednesday
# 3   3500   5500   2500   thursday
# 4   4000   3000   3000     friday
# 5   5300   4300   5300   saturday
# 6   7900   5900   6000     sunday

# %%
df.plot(kind="line",x="day")
plt.show()

# %%
df.plot(kind="bar",color=["r","g","b"],x="day",edgecolor="black")

plt.ylabel("weekly sales")
plt.xlabel("week days")
plt.show()

# %%
df.plot(kind="scatter",x="week1",y="week2")
# Out:
# <Axes: xlabel='week1', ylabel='week2'>

# %%
index_col=pd.Series(["English","Maths","Hindi","Science","Social_Studies"])
index_row=pd.Series(["Rishika Batra","Waseem Ali","Kulpreet Singh","Annie Mathews","Shiksha","Naveen Gupta","Taleem Ahmed","Pragati Nigam","Usman Abbas","Gurpreet Kaur","Sameer Muthy","Angelina","Angad Bedi"])
row1=pd.Series([95,95,90,94,95],index=index_col)
row2=pd.Series([95,76,79,77,89],index=index_col)
row3=pd.Series([78,81,75,76,88],index=index_col)
row4=pd.Series([88,63,67,77,80],index=index_col)
row5=pd.Series([95,55,51,59,80],index=index_col)
row6=pd.Series([82,55,63,56,74],index=index_col)
row7=pd.Series([73,49,54,60,77],index=index_col)
row8=pd.Series([80,50,51,54,76],index=index_col)
row9=pd.Series([92,43,51,48,69],index=index_col)
row10=pd.Series([60,43,55,52,71],index=index_col)
row11=pd.Series([60,43,55,52,71],index=index_col)
row12=pd.Series([78,33,39,48,68],index=index_col)
row13=pd.Series([62,43,51,48,54],index=index_col)
df1=pd.DataFrame([row1,row2,row3,row4,row5,row6,row7,row8,row9,row10,row11,row12,row13],index=index_row)
df1
# Out:
#                 English  Maths  Hindi  Science  Social_Studies
# Rishika Batra        95     95     90       94              95
# Waseem Ali           95     76     79       77              89
# Kulpreet Singh       78     81     75       76              88
# Annie Mathews        88     63     67       77              80
# Shiksha              95     55     51       59              80
# Naveen Gupta         82     55     63       56              74
# Taleem Ahmed         73     49     54       60              77
# Pragati Nigam        80     50     51       54              76
# Usman Abbas          92     43     51       48              69
# Gurpreet Kaur        60     43     55       52              71
# Sameer Muthy         60     43     55       52              71
# Angelina             78     33     39       48              68
# Angad Bedi           62     43     51       48              54

# %% [raw]
# df1.to_csv(r"/home/rguktrkvalley/Documents/Marks.csv")

# %%
df1.to_csv(r"/home/rguktrkvalley/Documents/Marks.csv")

# %%
df1.plot(kind="box")
# Out:
# <Axes: >

# %%
import pandas as pd
df=pd.DataFrame({"maths":[12,13,14],"science":[20,30,40],"phy":[12,35,45],"bio":[15,34,33]},index=["rak","sri","pandu"])
df
# Out:
#        maths  science  phy  bio
# rak       12       20   12   15
# sri       13       30   35   34
# pandu     14       40   45   33

# %%
df.plot(kind="box")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
forestcover=[67353,27692,17280,17321,19240,13464,8073]
plt.pie(forestcover,labels=["Arunachal Pradesh","Assam","Manipur","Meghalaya","Mizoram","Nagaland","Tripura"])
plt.show()

# %%
import pandas as pd

# %%
df=pd.DataFrame({"State":["Arunachal Pradesh","Assam","Manipur","Meghalaya","Mizoram","Nagaland","Tripura"],"ForestCover":[67353,27692,17280,17321,19240,13464,8073]})
df.plot(kind="pie",y="ForestCover",labels=df.State)
# Out:
# <Axes: ylabel='ForestCover'>

# %%
#histogram
import numpy as np
data=np.array([1,2,3,4,5,6])
plt.hist(data,bins=10,color="red",edgecolor="black")
plt.xlabel("hi")
plt.ylabel("hello")
# Out:
# Text(0, 0.5, 'hello')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,10,1,15,20])
df=pd.DataFrame(x)
df.plot(kind="hist",edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
pip install pywaffle
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f81c6b8a130>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pywaffle/
# Collecting pywaffle
#   Downloading pywaffle-1.1.0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting fontawesomefree (from pywaffle)
#   Downloading fontawesomefree-6.5.1-py3-none-any.whl.metadata (824 bytes)
# Requirement already satisfied: matplotlib in ./notebookenv/lib/python3.8/site-packages (from pywaffle) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->pywaffle) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in ./notebookenv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->pywaffle) (3.17.0)
# Requirement already satisfied: six>=1.5 in ./notebookenv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)
# Downloading pywaffle-1.1.0-py2.py3-none-any.whl (30 kB)
# Downloading fontawesomefree-6.5.1-py3-none-any.whl (25.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 168.6 kB/s eta 0:00:00m eta 0:00:010:00:04
# Installing collected packages: fontawesomefree, pywaffle
# Successfully installed fontawesomefree-6.5.1 pywaffle-1.1.0
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle
fig=plt.figure(FigureClass=Waffle,rows=3,values=[10,20,50],labels=["one","two","three"],columns=4)
plt.title("waffle chart")
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in ./notebookenv/lib/python3.8/site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: pillow in ./notebookenv/lib/python3.8/site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in ./notebookenv/lib/python3.8/site-packages (from wordcloud) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./notebookenv/lib/python3.8/site-packages (from matplotlib->wordcloud) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in ./notebookenv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in ./notebookenv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (520 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.1/520.1 kB 180.9 kB/s eta 0:00:000:00:010:00:01:01
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text="python is high level prog lang it is most widely used lang high cost python"
a=WordCloud(width=400,height=300,background_color="white").generate(text)
plt.imshow(a)
plt.show()
