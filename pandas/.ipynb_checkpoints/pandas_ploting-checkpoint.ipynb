# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("alphabet_stock_data.csv")

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# 4    1186.510010  2387300
# ..           ...      ...
# 122  1428.290039  1450200
# 123  1444.959961  1323000
# 124  1464.520020  2007900
# 125  1469.329956   978200
# 126  1469.599976  1700600
#
# [127 rows x 7 columns]

# %% [markdown]
# # Description of Dataset:
#
#     Date: It gives the date of which stocks details are given.
#     Open: It gives the opening price of stock on that date.
#     High: It gives the highest price to which the stock ascened on that day.
#     Low: It gives the highest price to which the stock plummeted on that day.
#     Close: It gives the closing price of stock on that date.
#     Volume: It gives the amount of stock traded on that date.
#     Adjusted Close: An adjusted closing price is a stock’s closing price on any given day of trading that has been amended to include any distributions and corporate actions that occurred at any time prior to the next day’s open.

# %% [markdown]
# ## 1. Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates.

# %%
new_df1=((df["Date"]>='2020-04-01') & (df["Date"]<="2020-09-30"))

# %%
new_df1
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 122    True
# 123    True
# 124    True
# 125    True
# 126    True
# Name: Date, Length: 127, dtype: bool

# %%
new_df=df[new_df1]
new_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# 4    1186.510010  2387300
# ..           ...      ...
# 122  1428.290039  1450200
# 123  1444.959961  1323000
# 124  1464.520020  2007900
# 125  1469.329956   978200
# 126  1469.599976  1700600
#
# [127 rows x 7 columns]

# %%
new_df.plot(x="Date",y="Close",kind="line",color="g")
plt.xlabel("DATE",fontsize=20)
plt.ylabel("$price")
plt.grid(axis="x")
plt.title("historical stock prices of Alphabet Inc. between two specific dates")
# Out:
# Text(0.5, 1.0, 'historical stock prices of Alphabet Inc. between two specific dates')

# %% [markdown]
# ## 2. Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
df[new_df1].iloc[:,[0,1,4]]
# Out:
#            Date         Open        Close
# 0    2020-04-01  1122.000000  1105.619995
# 1    2020-04-02  1098.260010  1120.839966
# 2    2020-04-03  1119.015015  1097.880005
# 3    2020-04-06  1138.000000  1186.920044
# 4    2020-04-07  1221.000000  1186.510010
# ..          ...          ...          ...
# 122  2020-09-24  1411.030029  1428.290039
# 123  2020-09-25  1432.630005  1444.959961
# 124  2020-09-28  1474.209961  1464.520020
# 125  2020-09-29  1470.390015  1469.329956
# 126  2020-09-30  1466.800049  1469.599976
#
# [127 rows x 3 columns]

# %%
new_df.plot(kind="line",x="Date",y=["Open","Close"])
plt.xlabel("Date")
plt.ylabel("$price")
plt.title("opening, closing stock prices between 2020-04-01 and 2020-09-30")
# Out:
# Text(0.5, 1.0, 'opening, closing stock prices between 2020-04-01 and 2020-09-30')

# %% [markdown]
# ## 3. Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.

# %%
new_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# 4    1186.510010  2387300
# ..           ...      ...
# 122  1428.290039  1450200
# 123  1444.959961  1323000
# 124  1464.520020  2007900
# 125  1469.329956   978200
# 126  1469.599976  1700600
#
# [127 rows x 7 columns]

# %%
n=(df["Date"]>='2020-04-01') & (df["Date"]<= '2020-04-30') 
new_df2=df[n]
new_df2.plot(kind="bar",x="Date",y="Volume")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("Trading Volume between 2020-04-01 and 2020-04-30")
# Out:
# Text(0.5, 1.0, 'Trading Volume between 2020-04-01 and 2020-04-30')

# %% [markdown]
# ## 4. Write a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
new_df2
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1   2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2   2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3   2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4   2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# 5   2020-04-08  1206.500000  1219.069946  1188.160034  1210.280029
# 6   2020-04-09  1224.079956  1225.569946  1196.734985  1211.449951
# 7   2020-04-13  1209.180054  1220.510010  1187.598022  1217.560059
# 8   2020-04-14  1245.089966  1282.069946  1236.930054  1269.229980
# 9   2020-04-15  1245.609985  1280.459961  1240.400024  1262.469971
# 10  2020-04-16  1274.099976  1279.000000  1242.619995  1263.469971
# 11  2020-04-17  1284.849976  1294.430054  1271.229980  1283.250000
# 12  2020-04-20  1271.000000  1281.599976  1261.369995  1266.609985
# 13  2020-04-21  1247.000000  1254.270020  1209.709961  1216.339966
# 14  2020-04-22  1245.540039  1285.613037  1242.000000  1263.209961
# 15  2020-04-23  1271.550049  1293.310059  1265.670044  1276.310059
# 16  2020-04-24  1261.170044  1280.400024  1249.449951  1279.310059
# 17  2020-04-27  1296.000000  1296.150024  1269.000000  1275.880005
# 18  2020-04-28  1287.930054  1288.050049  1232.199951  1233.670044
# 19  2020-04-29  1341.459961  1359.989990  1325.339966  1341.479980
# 20  2020-04-30  1324.880005  1352.819946  1322.489990  1348.660034
#
#       Adj Close   Volume
# 0   1105.619995  2343100
# 1   1120.839966  1964900
# 2   1097.880005  2313400
# 3   1186.920044  2664700
# 4   1186.510010  2387300
# 5   1210.280029  1975100
# 6   1211.449951  2175400
# 7   1217.560059  1739800
# 8   1269.229980  2470400
# 9   1262.469971  1671700
# 10  1263.469971  2518100
# 11  1283.250000  1949000
# 12  1266.609985  1695500
# 13  1216.339966  2153000
# 14  1263.209961  2093100
# 15  1276.310059  1566200
# 16  1279.310059  1640400
# 17  1275.880005  1600600
# 18  1233.670044  2951300
# 19  1341.479980  3793600
# 20  1348.660034  2665400

# %%
new_df2.plot(kind="bar",x="Date",y=["Open","Close"])
plt.xlabel("Date")
plt.ylabel("$price")
plt.title("opening, closing stock prices between 2020-04-01 and 2020-09-30")
# Out:
# Text(0.5, 1.0, 'opening, closing stock prices between 2020-04-01 and 2020-09-30')

# %% [markdown]
# ## 5. Write a Pandas program to create a stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
new_df2.plot(kind="bar",x="Date",y=["Open","Close"],stacked=True)
plt.xlabel("Date")
plt.ylabel("$price")
plt.title("opening, closing stock prices between 2020-04-01 and 2020-09-30")
# Out:
# Text(0.5, 1.0, 'opening, closing stock prices between 2020-04-01 and 2020-09-30')

# %% [markdown]
# ## 6. Write a Pandas program to create a horizontal stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
new_df2.plot(kind="barh",x="Date",y=["Open","Close"],stacked=True)
plt.xlabel("Date")
plt.ylabel("$price")
plt.title("opening, closing stock prices between 2020-04-01 and 2020-09-30")
# Out:
# Text(0.5, 1.0, 'opening, closing stock prices between 2020-04-01 and 2020-09-30')

# %% [markdown]
# ## 7. Write a Pandas program to create a histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
new_df2
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1   2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2   2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3   2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4   2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# 5   2020-04-08  1206.500000  1219.069946  1188.160034  1210.280029
# 6   2020-04-09  1224.079956  1225.569946  1196.734985  1211.449951
# 7   2020-04-13  1209.180054  1220.510010  1187.598022  1217.560059
# 8   2020-04-14  1245.089966  1282.069946  1236.930054  1269.229980
# 9   2020-04-15  1245.609985  1280.459961  1240.400024  1262.469971
# 10  2020-04-16  1274.099976  1279.000000  1242.619995  1263.469971
# 11  2020-04-17  1284.849976  1294.430054  1271.229980  1283.250000
# 12  2020-04-20  1271.000000  1281.599976  1261.369995  1266.609985
# 13  2020-04-21  1247.000000  1254.270020  1209.709961  1216.339966
# 14  2020-04-22  1245.540039  1285.613037  1242.000000  1263.209961
# 15  2020-04-23  1271.550049  1293.310059  1265.670044  1276.310059
# 16  2020-04-24  1261.170044  1280.400024  1249.449951  1279.310059
# 17  2020-04-27  1296.000000  1296.150024  1269.000000  1275.880005
# 18  2020-04-28  1287.930054  1288.050049  1232.199951  1233.670044
# 19  2020-04-29  1341.459961  1359.989990  1325.339966  1341.479980
# 20  2020-04-30  1324.880005  1352.819946  1322.489990  1348.660034
#
#       Adj Close   Volume
# 0   1105.619995  2343100
# 1   1120.839966  1964900
# 2   1097.880005  2313400
# 3   1186.920044  2664700
# 4   1186.510010  2387300
# 5   1210.280029  1975100
# 6   1211.449951  2175400
# 7   1217.560059  1739800
# 8   1269.229980  2470400
# 9   1262.469971  1671700
# 10  1263.469971  2518100
# 11  1283.250000  1949000
# 12  1266.609985  1695500
# 13  1216.339966  2153000
# 14  1263.209961  2093100
# 15  1276.310059  1566200
# 16  1279.310059  1640400
# 17  1275.880005  1600600
# 18  1233.670044  2951300
# 19  1341.479980  3793600
# 20  1348.660034  2665400

# %%
new_df.plot(kind="hist",x="Date",y=["Open","Close","High","Low"],color=["r","orange","g","brown"],alpha=0.5)
plt.xlabel("Date")
plt.ylabel("Frequency")
plt.title("opening, closing,High,Low stock prices between 2020-04-01 and 2020-09-30")
# Out:
# Text(0.5, 1.0, 'opening, closing,High,Low stock prices between 2020-04-01 and 2020-09-30')

# %% [markdown]
# ## 8. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
new_df.plot(kind="hist",x="Date",y=["Open","Close","High","Low"],color=["r","orange","g","brown"],stacked=True,bins=20)
plt.xlabel("Date")
plt.ylabel("Frequency")
plt.title("opening, closing,High,Low stock prices between 2020-04-01 and 2020-09-30")
# Out:
# Text(0.5, 1.0, 'opening, closing,High,Low stock prices between 2020-04-01 and 2020-09-30')

# %% [markdown]
# ## 9. Write a Pandas program to draw a horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc. between two specific dates.

# %%
new_df2.plot(kind="hist",x="Date",y="Open",orientation="horizontal",cumulative=True)
plt.xlabel("Date")
plt.ylabel("Frequency")
plt.title("opening, closing,High,Low stock prices between 2020-04-01 and 2020-04-30")
# Out:
# Text(0.5, 1.0, 'opening, closing,High,Low stock prices between 2020-04-01 and 2020-04-30')

# %% [markdown]
# ## 10. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates with more bins.

# %%
new_df.plot(kind="hist",x="Date",y=["Open","Close","High","Low"],color=["r","orange","g","brown"],stacked=True,bins=200)
plt.ylabel("Frequency")
plt.title("opening, closing,High,Low stock prices between 2020-04-01 and 2020-09-30")
# Out:
# Text(0.5, 1.0, 'opening, closing,High,Low stock prices between 2020-04-01 and 2020-09-30')

# %% [markdown]
# ## 11. Write a Pandas program to create a stacked histograms plot with more bins of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
new_df
df2=new_df[["Open","Close","High","Low"]]
df2.hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>]], dtype=object)

# %% [markdown]
# ## 12. Write a Pandas program to create a plot of stock price and trading volume of Alphabet Inc. between two specific dates.

# %%
new_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# 4    1186.510010  2387300
# ..           ...      ...
# 122  1428.290039  1450200
# 123  1444.959961  1323000
# 124  1464.520020  2007900
# 125  1469.329956   978200
# 126  1469.599976  1700600
#
# [127 rows x 7 columns]

# %%
new_df2["Volume"].plot(kind="bar")
# Out:
# <Axes: >

# %%
new_df["Volume"].plot(kind="line")
# Out:
# <Axes: >

# %% [markdown]
# ## 13. Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of Alphabet Inc. between two specific dates.

# %%
new_df.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %% [markdown]
# ## 14. Write a Pandas program to create a plot of adjusted closing prices, thirty days and forty days simple moving average of Alphabet Inc. between two specific dates.
#
#
# What Is Simple Moving Average (SMA)?
# A simple moving average (SMA) is an arithmetic moving average calculated by adding recent prices and then dividing that figure by the number of time periods in the calculation average. For example, one could add the closing price of a security for a number of time periods and then divide this total by that same number of periods. Short-term averages respond quickly to changes in the price of the underlying security, while long-term averages are slower to react.

# %%
new_df["Adj Close"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## 16. Write a Pandas program to create a scatter plot of the trading volume/stock prices of Alphabet Inc. stock between two specific dates.

# %%
new_df2
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1   2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2   2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3   2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4   2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# 5   2020-04-08  1206.500000  1219.069946  1188.160034  1210.280029
# 6   2020-04-09  1224.079956  1225.569946  1196.734985  1211.449951
# 7   2020-04-13  1209.180054  1220.510010  1187.598022  1217.560059
# 8   2020-04-14  1245.089966  1282.069946  1236.930054  1269.229980
# 9   2020-04-15  1245.609985  1280.459961  1240.400024  1262.469971
# 10  2020-04-16  1274.099976  1279.000000  1242.619995  1263.469971
# 11  2020-04-17  1284.849976  1294.430054  1271.229980  1283.250000
# 12  2020-04-20  1271.000000  1281.599976  1261.369995  1266.609985
# 13  2020-04-21  1247.000000  1254.270020  1209.709961  1216.339966
# 14  2020-04-22  1245.540039  1285.613037  1242.000000  1263.209961
# 15  2020-04-23  1271.550049  1293.310059  1265.670044  1276.310059
# 16  2020-04-24  1261.170044  1280.400024  1249.449951  1279.310059
# 17  2020-04-27  1296.000000  1296.150024  1269.000000  1275.880005
# 18  2020-04-28  1287.930054  1288.050049  1232.199951  1233.670044
# 19  2020-04-29  1341.459961  1359.989990  1325.339966  1341.479980
# 20  2020-04-30  1324.880005  1352.819946  1322.489990  1348.660034
#
#       Adj Close   Volume
# 0   1105.619995  2343100
# 1   1120.839966  1964900
# 2   1097.880005  2313400
# 3   1186.920044  2664700
# 4   1186.510010  2387300
# 5   1210.280029  1975100
# 6   1211.449951  2175400
# 7   1217.560059  1739800
# 8   1269.229980  2470400
# 9   1262.469971  1671700
# 10  1263.469971  2518100
# 11  1283.250000  1949000
# 12  1266.609985  1695500
# 13  1216.339966  2153000
# 14  1263.209961  2093100
# 15  1276.310059  1566200
# 16  1279.310059  1640400
# 17  1275.880005  1600600
# 18  1233.670044  2951300
# 19  1341.479980  3793600
# 20  1348.660034  2665400

# %%
new_df.plot(kind="scatter",x="Close",y="Volume")
plt.grid()
plt.xlabel("Close")
plt.ylabel("Volume")
plt.title("trading volume/stock prices ")
# Out:
# Text(0.5, 1.0, 'trading volume/stock prices ')
