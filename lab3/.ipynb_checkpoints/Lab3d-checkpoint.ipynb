# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from pywaffle import Waffle

# %%
fig=plt.figure(FigureClass=Waffle,rows=7,columns=5,values=[10,12,13],labels=["Group1","Group2","Group3"])
plt.title("Waffle Chart")
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>
