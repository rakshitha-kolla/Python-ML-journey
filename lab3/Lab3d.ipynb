# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from pywaffle import Waffle

# %%
fig=plt.figure(FigureClass=Waffle,rows=5,columns=10,values=[10,12,13],labels=["Group1","Group2","Group3"])
plt.title("Waffle Chart")
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text="python is high level prog lang it is most widely used lang high cost python k"
a=WordCloud(width=400,height=300,background_color="white").generate(text)
plt.imshow(a)
