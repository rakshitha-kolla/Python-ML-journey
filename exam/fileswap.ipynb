# %%
file_path1="one.txt"
file_path2="two.txt"
file1=open(file_path1,"r")
file1_con=file1.read()
print(file1_con)
file2=open(file_path2,"r")
file2_con=file2.read()
file1=open(file_path1,'w')
file1.write(file2_con)
file2=open(file_path2,'w')
file2.write(file1_con)
print("Contents swapped successfully!")
file1.close()
file2.close()
file1=open(file_path1,"r")
print(file1.readline())
print(file1.readline())
# Out:
# hi i am 1
# i qwerty
# Contents swapped successfully!
# hi am 2
#
# this is incredible

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
type_of_sports=['golf','tennis','football','rugby','basket ball']
num_of_stu=[6,8,13,10,17]
plt.bar(type_of_sports,num_of_stu,color=['red','grey','pink','orange','blue'])
plt.title("sports")
plt.xlabel("types of sports")
plt.ylabel("number of students")

plt.show()
