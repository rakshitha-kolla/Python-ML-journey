# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

X = np.array([10, 20, 30, 40, 50]).reshape(-1,1)
y = np.array([30, 40, 20, 40, 50]).reshape(-1,1)
df=pd.DataFrame([X,y])
print(df)
model = LinearRegression()

model.fit(X, y)

intercept = model.intercept_
coefficient = model.coef_[0]
y_pred = model.predict(X)

mse = mean_squared_error(y, y_pred)
mae = mean_absolute_error(y, y_pred)
r_squared = r2_score(y, y_pred)

print("Intercept:", intercept)
print("Coefficient:", coefficient)
print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared Error:", r_squared)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 8
#       6 X = np.array([10, 20, 30, 40, 50]).reshape(-1,1)
#       7 y = np.array([30, 40, 20, 40, 50]).reshape(-1,1)
# ----> 8 df=pd.DataFrame([X,y])
#       9 print(df)
#      10 model = LinearRegression()
#
# File ~/test/notebookenv/lib/python3.8/site-packages/pandas/core/frame.py:798, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     790         mgr = arrays_to_mgr(
#     791             arrays,
#     792             columns,
#    (...)
#     795             typ=manager,
#     796         )
#     797     else:
# --> 798         mgr = ndarray_to_mgr(
#     799             data,
#     800             index,
#     801             columns,
#     802             dtype=dtype,
#     803             copy=copy,
#     804             typ=manager,
#     805         )
#     806 else:
# ...

# %%
def swap_files(file1, file2):
    try:
        with open(file1, 'r') as f1:
            data1 = f1.read()

      
        with open(file2, 'r') as f2:
            data2 = f2.read()

       
        with open(file2, 'w') as f2:
            f2.write(data1)

      
        with open(file1, 'w') as f1:
            f1.write(data2)

        print("Contents of files swapped successfully!")
    except FileNotFoundError:
        print("One or both files not found.")



file1 = 'file1.txt'
file2 = 'file2.txt'

swap_files(file1, file2)
# Out:
# Contents of files swapped successfully!

# %%
import matplotlib.pyplot as plt
categories=["golf","tennis","football","rugby","basketball"]
values=[6,8,12,10,16]
plt.bar(categories,values,color=["orange","green","red","blue","aqua"])
plt.title("sports")
plt.xlabel("TYPES OF SPORTS")
plt.ylabel("NUMBER OF STUDENTS")
plt.show()
