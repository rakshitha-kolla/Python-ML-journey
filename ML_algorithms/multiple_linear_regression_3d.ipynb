# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_regression
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y=make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
X
# Out:
# array([[-2.34591574, -0.93992728],
#        [ 0.98327976, -0.52882978],
#        [-0.59453867,  0.56433816],
#        [ 0.58261141, -0.55619979],
#        [ 0.65819065, -0.71658275],
#        [ 0.31236977, -1.58025003],
#        [ 1.77003319, -0.71394003],
#        [ 0.0459187 ,  0.38206372],
#        [-0.1196562 ,  0.78480538],
#        [ 0.70321169, -1.44881931],
#        [-0.53126193,  0.34795238],
#        [ 0.74977243, -0.38167879],
#        [-0.24315019,  2.16182613],
#        [-1.30912029, -0.83320843],
#        [-1.01487975,  0.15328172],
#        [ 0.22197014,  0.92406916],
#        [ 1.23973159, -1.59751458],
#        [ 1.52594102,  0.96404888],
#        [-0.49252123,  0.76457179],
#        [-1.11764159, -1.63922617],
#        [-0.87569168,  0.26746383],
#        [ 1.06829556,  0.21120321],
#        [-1.36402935, -1.47548749],
#        [-0.00340851, -0.96647132],
#        [ 0.1808789 , -0.62878003],
#        [-0.15373866, -0.31192589],
#        [ 1.82760942,  1.34458909],
#        [ 0.26674979, -1.03521678],
#        [ 0.29862851,  0.92964151],
#        [ 0.12936148,  0.26679259],
#        [-0.53622044, -0.60436599],
#        [-1.69083221,  1.13745533],
#        [-1.63582658,  0.66180658],
#        [-0.40877543,  0.45169566],
#        [-0.16713994, -0.12779789],
#        [-0.35855655,  0.00946619],
#        [-1.79669021, -1.68679958],
#        [ 0.48299388,  0.74263457],
#        [-0.27778585, -0.11565779],
#        [-0.14206844, -1.46599425],
#        [-0.94827575, -0.28514105],
#        [ 1.69012641, -0.99833064],
#        [ 1.07639866,  0.32997939],
#        [ 0.06181245,  1.96926297],
#        [-0.46398272, -0.39862944],
#        [-1.54824452, -0.72650672],
#        [ 1.14658079,  2.1301889 ],
#        [-0.91589796, -0.4200739 ],
#        [-0.54379719, -0.07627888],
#        [-0.48868609, -0.29942427],
#        [ 1.81778649,  0.19248116],
#        [-0.08511285,  1.11310147],
#        [-0.36425768, -1.01028619],
#        [-0.13160231,  0.08715357],
#        [-0.13673168,  0.6576734 ],
#        [ 0.33684963, -0.63886985],
#        [ 0.50541294,  1.93118087],
#        [-0.76638173, -1.38700774],
#        [-1.02689885, -0.72498689],
#        [-1.02719084, -0.44188907],
#        [ 0.20525132, -1.48216008],
#        [-1.59508118, -0.45651515],
#        [-1.91490434, -0.55907003],
#        [ 0.50531558,  0.78979952],
#        [-0.31757091, -0.49440727],
#        [ 1.13117816,  2.05044998],
#        [-0.23422598, -0.27094233],
#        [ 0.34688326,  0.08757004],
#        [-1.02983543,  1.62185875],
#        [ 0.66471475,  1.31260215],
#        [ 1.37116099,  0.3292035 ],
#        [-0.18147276, -0.42870134],
#        [-0.04149881, -0.401608  ],
#        [-1.06947282,  0.04459155],
#        [ 0.05763156, -0.58425397],
#        [-1.26611551, -0.3755834 ],
#        [-0.30837355,  0.63680499],
#        [-1.19550258, -0.3425217 ],
#        [ 0.05232941,  0.38520464],
#        [-0.67548168,  0.30574189],
#        [ 0.61635497,  1.31191589],
#        [ 0.06523274, -0.76675166],
#        [-0.09476582,  0.78819455],
#        [ 1.29479347,  0.5890481 ],
#        [ 1.01899447,  0.56437645],
#        [-1.29126797, -0.38556875],
#        [-0.27204135,  0.18023807],
#        [-0.89681997,  0.86311914],
#        [ 0.52507498,  1.00040185],
#        [ 0.19275049, -0.83788028],
#        [ 0.67843689, -0.45663126],
#        [-0.14390895, -1.21529039],
#        [-1.29169131, -0.7949622 ],
#        [-0.43209207, -0.04992576],
#        [ 0.64798493, -2.42894888],
#        [ 0.92972504, -0.29508258],
#        [ 1.59579082, -2.25078198],
#        [-0.58272267,  0.09595147],
#        [ 1.46827897,  1.24895513],
#        [ 0.73732223,  0.54421096]])

# %%
y
# Out:
# array([-237.16325661,    9.88909735,   56.70558546,   65.76203363,
#           9.17112634, -195.0023865 ,  107.97830195,   65.42767432,
#          20.80360357, -118.73303715,  -35.24888917,   15.9988061 ,
#         193.59963562, -115.76644952,  -94.43587813,  221.56801026,
#         -54.50421078,  130.32182988,   54.69994163, -259.55701574,
#         -60.01975088,   59.82183123, -223.78912527, -164.41028807,
#         -98.81510056, -129.89009417,  228.78301394,  -77.18674754,
#          16.49049867,  -24.24869783,  -75.88635729,   56.72881981,
#         -87.65161271,   63.96107027,  -91.21933142,  -65.17916916,
#        -304.96407968,  105.99315125,  -64.11927817, -105.26320462,
#        -172.10917412,   83.67333718,   70.71349412,  152.03676854,
#         -38.70974898, -212.72304161,  281.43315214, -158.71309605,
#         -63.02916592,  -88.86135547,  198.12665726,  144.96956051,
#        -129.55925589,  -34.43970609,   -7.30113134,  -94.38269069,
#         274.19845268, -145.30688494, -126.19144267,  -74.00982639,
#        -252.72801762, -218.22057934, -189.85323563,  150.48623468,
#         -56.62708814,  294.81427278,  -98.7791404 ,   20.56975803,
#          54.80660549,  149.75592861,  133.95536702,   11.77236235,
#         -54.60754814,  -56.52588008,  -27.99083656, -141.15921678,
#          46.34582285, -193.19203985,   48.46266541,  -93.63368855,
#         288.31295395,  -53.2220324 ,    9.21913583,   52.92879357,
#         140.22122787, -135.51717908,   51.71911762,  -20.01655358,
#         136.26114418, -129.67060611,  166.15499532, -212.31001652,
#        -246.02336119,  -75.2754202 , -187.08484361,   18.87672956,
#        -116.17334137,   -9.92884333,  232.10370753,   57.56240336])

# %%
X.shape
# Out:
# (100, 2)

# %%
df=pd.DataFrame({"feature1":X[:,0],"feature2":X[:,1],"target":y})

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0 -2.345916 -0.939927 -237.163257
# 1  0.983280 -0.528830    9.889097
# 2 -0.594539  0.564338   56.705585
# 3  0.582611 -0.556200   65.762034
# 4  0.658191 -0.716583    9.171126

# %%
df.shape
# Out:
# (100, 3)

# %%
fig=px.scatter_3d(df,x="feature1",y="feature2",z="target")
fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=3)

# %%
X_train
# Out:
# array([[-1.06947282,  0.04459155],
#        [-0.24315019,  2.16182613],
#        [-0.1196562 ,  0.78480538],
#        [ 0.65819065, -0.71658275],
#        [-0.67548168,  0.30574189],
#        [-0.27204135,  0.18023807],
#        [ 1.52594102,  0.96404888],
#        [ 1.13117816,  2.05044998],
#        [-0.91589796, -0.4200739 ],
#        [ 1.81778649,  0.19248116],
#        [-0.53622044, -0.60436599],
#        [ 0.31236977, -1.58025003],
#        [-1.30912029, -0.83320843],
#        [-1.69083221,  1.13745533],
#        [ 0.52507498,  1.00040185],
#        [ 0.74977243, -0.38167879],
#        [-1.02689885, -0.72498689],
#        [-1.29126797, -0.38556875],
#        [-1.63582658,  0.66180658],
#        [-0.94827575, -0.28514105],
#        [ 1.23973159, -1.59751458],
#        [ 0.26674979, -1.03521678],
#        [-0.35855655,  0.00946619],
#        [-1.79669021, -1.68679958],
#        [-1.29169131, -0.7949622 ],
#        [ 0.67843689, -0.45663126],
#        [ 0.05232941,  0.38520464],
#        [-0.30837355,  0.63680499],
#        [-1.02983543,  1.62185875],
#        [ 1.14658079,  2.1301889 ],
#        [-0.13160231,  0.08715357],
#        [ 1.37116099,  0.3292035 ],
#        [ 0.61635497,  1.31191589],
#        [-1.59508118, -0.45651515],
#        [-0.49252123,  0.76457179],
#        [-0.14390895, -1.21529039],
#        [-0.76638173, -1.38700774],
#        [ 0.92972504, -0.29508258],
#        [-0.13673168,  0.6576734 ],
#        [ 0.33684963, -0.63886985],
#        [ 0.29862851,  0.92964151],
#        [-0.36425768, -1.01028619],
#        [ 1.01899447,  0.56437645],
#        [ 0.19275049, -0.83788028],
#        [-0.48868609, -0.29942427],
#        [-0.89681997,  0.86311914],
#        [ 0.48299388,  0.74263457],
#        [-0.54379719, -0.07627888],
#        [-0.40877543,  0.45169566],
#        [ 0.06181245,  1.96926297],
#        [ 0.0459187 ,  0.38206372],
#        [-1.91490434, -0.55907003],
#        [ 0.73732223,  0.54421096],
#        [ 0.12936148,  0.26679259],
#        [ 0.66471475,  1.31260215],
#        [-0.08511285,  1.11310147],
#        [ 0.98327976, -0.52882978],
#        [ 0.20525132, -1.48216008],
#        [ 0.50531558,  0.78979952],
#        [-0.59453867,  0.56433816],
#        [-0.23422598, -0.27094233],
#        [-1.36402935, -1.47548749],
#        [ 0.06523274, -0.76675166],
#        [ 1.82760942,  1.34458909],
#        [-1.01487975,  0.15328172],
#        [-0.14206844, -1.46599425],
#        [-0.46398272, -0.39862944],
#        [-0.87569168,  0.26746383],
#        [-0.27778585, -0.11565779],
#        [ 0.64798493, -2.42894888],
#        [-0.53126193,  0.34795238],
#        [ 1.69012641, -0.99833064],
#        [ 0.05763156, -0.58425397],
#        [-1.11764159, -1.63922617],
#        [ 1.06829556,  0.21120321],
#        [-2.34591574, -0.93992728],
#        [-0.04149881, -0.401608  ],
#        [ 0.50541294,  1.93118087],
#        [ 0.58261141, -0.55619979],
#        [ 0.1808789 , -0.62878003]])

# %%
y_train
# Out:
# array([ -56.52588008,  193.59963562,   20.80360357,    9.17112634,
#         -93.63368855,   51.71911762,  130.32182988,  294.81427278,
#        -158.71309605,  198.12665726,  -75.88635729, -195.0023865 ,
#        -115.76644952,   56.72881981,  136.26114418,   15.9988061 ,
#        -126.19144267, -135.51717908,  -87.65161271, -172.10917412,
#         -54.50421078,  -77.18674754,  -65.17916916, -304.96407968,
#        -246.02336119,  166.15499532,   48.46266541,   46.34582285,
#          54.80660549,  281.43315214,  -34.43970609,  133.95536702,
#         288.31295395, -218.22057934,   54.69994163, -212.31001652,
#        -145.30688494,   18.87672956,   -7.30113134,  -94.38269069,
#          16.49049867, -129.55925589,  140.22122787, -129.67060611,
#         -88.86135547,  -20.01655358,  105.99315125,  -63.02916592,
#          63.96107027,  152.03676854,   65.42767432, -189.85323563,
#          57.56240336,  -24.24869783,  149.75592861,  144.96956051,
#           9.88909735, -252.72801762,  150.48623468,   56.70558546,
#         -98.7791404 , -223.78912527,  -53.2220324 ,  228.78301394,
#         -94.43587813, -105.26320462,  -38.70974898,  -60.01975088,
#         -64.11927817, -187.08484361,  -35.24888917,   83.67333718,
#         -27.99083656, -259.55701574,   59.82183123, -237.16325661,
#         -54.60754814,  274.19845268,   65.76203363,  -98.81510056])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([ -43.91119968,   28.96062128,   58.91797929,  -78.7427316 ,
#        -104.99361887,  150.38740162,  228.29291884,  108.34376154,
#         -48.36573857,  101.42141693, -130.79758444,  -94.4512801 ,
#         -61.92558729,  -41.09916402,  -31.34118752, -139.42210493,
#          63.95364247, -101.05524176, -127.70302536, -195.32806387])

# %%
y_test
# Out:
# array([ -75.2754202 ,   20.56975803,  107.97830195,  -56.62708814,
#        -116.17334137,   52.92879357,  232.10370753,   70.71349412,
#        -129.89009417,  221.56801026, -193.19203985, -118.73303715,
#          11.77236235,   -9.92884333,  -91.21933142, -141.15921678,
#           9.21913583, -164.41028807,  -74.00982639, -212.72304161])

# %%
print("MSR=",mean_squared_error(y_test,y_pred))
print("MAR=",mean_absolute_error(y_test,y_pred))
print("r2_score=",r2_score(y_test,y_pred))
# Out:
# MSR= 3037.730951759834
# MAR= 45.25094268300186
# r2_score= 0.7963234519908173

# %%
lr.coef_
# Out:
# array([76.24870618, 98.00997636])

# %%
lr.intercept_
# Out:
# np.float64(-6.071515672311238)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 fig=px.scatter_3d(df,x="feature1",y="feature2",z="target")
# ----> 2 fig.add_trace(go.surface(x=x,y=y,z=z))
#       3 fig.show()
#
# NameError: name 'x' is not defined
