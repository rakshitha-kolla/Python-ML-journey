# %%
import matplotlib.pyplot as plt

# %%
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
plt.plot(weight,height,color='g',marker='*',markersize=10,ls='dashed',linewidth=2)

plt.xlabel("Weight in kg")
plt.title('Average weight with respect to average height')
plt.grid(True)
plt.show()

# %%
import pandas as pd

# %%
df1=pd.read_csv("MelaSales.csv")
print(df1)
# Out:
#    Week1  Week2  Week3        Day
# 0   5000   4000   4000     Monday
# 1   5900   3000   5800    Tuesday
# 2   6500   5000   3500  Wednesday
# 3   3500   5500   2500   Thursday
# 4   4000   3000   3000     Friday
# 5   5300   4300   5300   Saturday
# 6   7900   5900   6000     Sunday

# %%
x=df1.Day
'''y1=df1.Week1
y2=df1.Week2
y3=df1.Week3'''
df1.plot(x="Day",color=['r','b','brown'],ylabel='Sales in Rs.')
plt.title("Mela Sales Report")
plt.xlabel("Days")
# Out:
# Text(0.5, 0, 'Days')

# %%
df1.plot(kind='bar',x="Day",color=['r','g','b'],xlabel='days',ylabel='Sales in Rs.')
# Out:
# <Axes: xlabel='days', ylabel='Sales in Rs.'>

# %%
from pywaffle import Waffle 
data ={'phone': ['Xiaomi', 'Samsung', 
                 'Apple', 'Nokia', 'Realme'], 
       'stock': [44, 12, 8, 5, 3] 
     } 
df = pd.DataFrame(data) 
fig = plt.figure( 
    FigureClass = Waffle, 
    rows = 6, 
    values = df.stock, 
    labels = list(df.phone) 
) 
plt.title("Waffle Chart")
# Out:
# Text(0.5, 1.0, 'Waffle Chart')
# <Waffle size 640x480 with 1 Axes>

# %%
pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.2 kB 262.6 kB/s eta 0:00:02
#    --- ----------------------------------- 30.7/300.2 kB 262.6 kB/s eta 0:00:02
#    ----------- --------------------------- 92.2/300.2 kB 403.5 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/300.2 kB 403.5 kB/s eta 0:00:01
#    --------------- ---------------------- 122.9/300.2 kB 379.3 kB/s eta 0:00:01
# ...

# %%
from wordcloud import WordCloud

# %%
text="hello world vfhbf klndjkew jnLODJ ASDJK SHFONCK DIOSJC LJNJFBL C .LCJ/NC. KLCNJSKFBIS MSCL"
a=WordCloud(width=1000,height=400,background_color='red').generate(text)
plt.imshow(a)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
l1={'Name':['Aparna','Pankaj','Ram','Ramesh','Naveen','Krrishnav','Bhawna'],
    'Degree':['MBA','BCA','M.TECH','MBA',np.nan,'BCA','MBA'],
    'Score':[90.0,np.nan,80.0,98.0,97.0,78.0,89.0]
    }
df=pd.DataFrame(l1)
print(df)
# Out:
#         Name  Degree  Score
# 0     Aparna     MBA   90.0
# 1     Pankaj     BCA    NaN
# 2        Ram  M.TECH   80.0
# 3     Ramesh     MBA   98.0
# 4     Naveen     NaN   97.0
# 5  Krrishnav     BCA   78.0
# 6     Bhawna     MBA   89.0

# %%
df=df.fillna(76)
print(df)
# Out:
#         Name  Degree  Score
# 0     Aparna     MBA   90.0
# 1     Pankaj     BCA   76.0
# 2        Ram  M.TECH   80.0
# 3     Ramesh     MBA   98.0
# 4     Naveen      76   97.0
# 5  Krrishnav     BCA   78.0
# 6     Bhawna     MBA   89.0

# %%
df['Score'].mean()
# Out:
# 86.85714285714286

# %%
df[df['Degree']=='BCA'].mode()
# Out:
#         Name Degree  Score
# 0  Krrishnav    BCA   76.0
# 1     Pankaj    NaN   78.0

# %%
l2={' ':['Madhu','Kusum','Kinshuk','Ankit','Shruti'],
    2014:[100.5,150.8,200.9,30000,50000],
    2015:[12000,18000,22000,30000,45000],
    2016:[20000,50000,70000,100000,125000],
    2017:[50000,60000,70000,80000,90000],
    }
df1=pd.DataFrame(l2)
df1.set_index(' ',inplace=True)
df1
# Out:
#             2014   2015    2016   2017
#
# Madhu      100.5  12000   20000  50000
# Kusum      150.8  18000   50000  60000
# Kinshuk    200.9  22000   70000  70000
# Ankit    30000.0  30000  100000  80000
# Shruti   50000.0  45000  125000  90000

# %%
l2={2014:[100.5,150.8,200.9,30000,50000],
    2015:[12000,18000,22000,30000,45000],
    2016:[20000,50000,70000,100000,125000],
    2017:[50000,60000,70000,80000,90000],
    }

df1=pd.DataFrame(l2)
df1.rename({0:"m",1:"a",2:"p",3:"q",4:"e"},axis='index')
#df1.set_index(' ',inplace=True)
df1
# Out:
#       2014   2015    2016   2017
# 0    100.5  12000   20000  50000
# 1    150.8  18000   50000  60000
# 2    200.9  22000   70000  70000
# 3  30000.0  30000  100000  80000
# 4  50000.0  45000  125000  90000
