# %%
import numpy as np
import pandas as pd
info= {
       'ID':['r200260','r200247','r200057','r200058','r200847'],
       'Name':['Pavan','Nithin','Prasad','Srujan','Arman'],
       'Marks':[28,29,30,35,24],
       'Phone':[7036006588,np.nan,8500050716,7416485585,np.nan],
       'Address':[np.nan,'Nuzvidu',np.nan,'IDUPULAPAAYA','Nellore']
       }
df=pd.DataFrame(info)
print(df)
# Out:
#         ID    Name  Marks         Phone       Address
# 0  r200260   Pavan     28  7.036007e+09           NaN
# 1  r200247  Nithin     29           NaN       Nuzvidu
# 2  r200057  Prasad     30  8.500051e+09           NaN
# 3  r200058  Srujan     35  7.416486e+09  IDUPULAPAAYA
# 4  r200847   Arman     24           NaN       Nellore

# %%
df.isnull()
# Out:
#       ID   Name  Marks  Phone  Address
# 0  False  False  False  False     True
# 1  False  False  False   True    False
# 2  False  False  False  False     True
# 3  False  False  False  False    False
# 4  False  False  False   True    False

# %%
df.isnull().any()
# Out:
# ID         False
# Name       False
# Marks      False
# Phone       True
# Address     True
# dtype: bool

# %%
df['Phone'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Phone, dtype: bool

# %%
df.dropna()
# Out:
#         ID    Name  Marks         Phone       Address
# 3  r200058  Srujan     35  7.416486e+09  IDUPULAPAAYA

# %%
df.fillna('Dont Know')
# Out:
#         ID    Name  Marks         Phone       Address
# 0  r200260   Pavan     28  7036006588.0     Dont Know
# 1  r200247  Nithin     29     Dont Know       Nuzvidu
# 2  r200057  Prasad     30  8500050716.0     Dont Know
# 3  r200058  Srujan     35  7416485585.0  IDUPULAPAAYA
# 4  r200847   Arman     24     Dont Know       Nellore

# %%
df.ffill()
# Out:
#         ID    Name  Marks         Phone       Address
# 0  r200260   Pavan     28  7.036007e+09           NaN
# 1  r200247  Nithin     29  7.036007e+09       Nuzvidu
# 2  r200057  Prasad     30  8.500051e+09       Nuzvidu
# 3  r200058  Srujan     35  7.416486e+09  IDUPULAPAAYA
# 4  r200847   Arman     24  7.416486e+09       Nellore

# %%
#step1 of data formatting--importing the data
df1=pd.read_csv("Private_data.csv")
df1
# Out:
#      Unnamed: 0 NAME OF THE STUDENT  \
# 0             0         Camila Wood
# 1             1  Alexander Thompson
# 2             2         Liam Taylor
# 3             3      Evelyn Jenkins
# 4             4     Michael Jackson
# ..          ...                 ...
# 146         146         Avery Lewis
# 147         147        Ethan Martin
# 148         148  Nicholas Rodriguez
# 149         149        Samuel Perez
# 150         150           Emily Lee
#
#                                            UNIVERSITY PROGRAM NAME  \
# 0                            Stanford University, USA        B.Com
# 1                            Stanford University, USA        B.Com
# 2                             Harvard University, USA        B.Com
# 3                            Stanford University, USA        B.Com
# 4                             Harvard University, USA          MBA
# ..                                                ...          ...
# 146                          Stanford University, USA          BBA
# 147                          Stanford University, USA          BBA
# 148                           Harvard University, USA          MBA
# 149                          Stanford University, USA          BBA
# 150  Massachusetts Institute of Technology (MIT), USA          BBA
#
#              Specialisation SEMESTER   Domain  \
# 0                   Honours      5th  Finance
# 1        Financial Services      5th  Finance
# 2      Accounting Analytics      5th       BA
# 3                   Honours      5th  Finance
# 4    International Business      3rd       IB
# ..                      ...      ...      ...
# 146      Financial Services      5th  Finance
# 147  International Business      5th  Generic
# 148  International Business      3rd       IB
# 149  International Business      5th       IB
# 150       Digital Marketing      5th       DM
#
#      GENERAL MANAGEMENT SCORE (OUT of 50)  Domain Specific SCORE (OUT 50)  \
# 0                                      50                              50
# 1                                      50                              50
# 2                                      50                              50
# 3                                      49                              50
# 4                                      50                              49
# ..                                    ...                             ...
# 146                                    16                              12
# 147                                    11                              13
# 148                                    16                               8
# 149                                    12                               8
# 150                                     4                               1
#
#      TOTAL SCORE (OUT of 100)  RANK  PERCENTILE
# 0                         100     1    1.000000
# 1                         100     2    0.993377
# 2                         100     3    0.986755
# 3                          99     4    0.980132
# 4                          99     5    0.973510
# ..                        ...   ...         ...
# 146                        28   147    0.033113
# 147                        24   148    0.026490
# 148                        24   149    0.019868
# 149                        20   150    0.013245
# 150                         5   151    0.006623
#
# [151 rows x 12 columns]

# %%
#step2--identifying the missing values
#1.for each cell
df1.isnull()
# Out:
#      Unnamed: 0  NAME OF THE STUDENT  UNIVERSITY  PROGRAM NAME  \
# 0         False                False       False         False
# 1         False                False       False         False
# 2         False                False       False         False
# 3         False                False       False         False
# 4         False                False       False         False
# ..          ...                  ...         ...           ...
# 146       False                False       False         False
# 147       False                False       False         False
# 148       False                False       False         False
# 149       False                False       False         False
# 150       False                False       False         False
#
#      Specialisation  SEMESTER  Domain  GENERAL MANAGEMENT SCORE (OUT of 50)  \
# 0             False     False   False                                 False
# 1             False     False   False                                 False
# 2             False     False   False                                 False
# 3             False     False   False                                 False
# 4             False     False   False                                 False
# ..              ...       ...     ...                                   ...
# 146           False     False   False                                 False
# 147           False     False   False                                 False
# 148           False     False   False                                 False
# 149           False     False   False                                 False
# 150           False     False   False                                 False
#
#      Domain Specific SCORE (OUT 50)  TOTAL SCORE (OUT of 100)   RANK  \
# 0                             False                     False  False
# 1                             False                     False  False
# 2                             False                     False  False
# 3                             False                     False  False
# 4                             False                     False  False
# ..                              ...                       ...    ...
# 146                           False                     False  False
# 147                           False                     False  False
# 148                           False                     False  False
# 149                           False                     False  False
# 150                           False                     False  False
#
#      PERCENTILE
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 146       False
# 147       False
# 148       False
# 149       False
# 150       False
#
# [151 rows x 12 columns]

# %%
#2.for each column
df1.isnull().any()
#There are no missing values in the exported files
# Out:
# Unnamed: 0                              False
# NAME OF THE STUDENT                     False
# UNIVERSITY                              False
# PROGRAM NAME                            False
# Specialisation                          False
# SEMESTER                                False
# Domain                                  False
# GENERAL MANAGEMENT SCORE (OUT of 50)    False
# Domain Specific SCORE (OUT 50)          False
# TOTAL SCORE (OUT of 100)                False
# RANK                                    False
# PERCENTILE                              False
# dtype: bool

# %%
#renaming the column
df2=df1.rename({"Unnamed: 0":"S.No"},axis=1)
df2
# Out:
#      S.No NAME OF THE STUDENT  \
# 0       0         Camila Wood
# 1       1  Alexander Thompson
# 2       2         Liam Taylor
# 3       3      Evelyn Jenkins
# 4       4     Michael Jackson
# ..    ...                 ...
# 146   146         Avery Lewis
# 147   147        Ethan Martin
# 148   148  Nicholas Rodriguez
# 149   149        Samuel Perez
# 150   150           Emily Lee
#
#                                            UNIVERSITY PROGRAM NAME  \
# 0                            Stanford University, USA        B.Com
# 1                            Stanford University, USA        B.Com
# 2                             Harvard University, USA        B.Com
# 3                            Stanford University, USA        B.Com
# 4                             Harvard University, USA          MBA
# ..                                                ...          ...
# 146                          Stanford University, USA          BBA
# 147                          Stanford University, USA          BBA
# 148                           Harvard University, USA          MBA
# 149                          Stanford University, USA          BBA
# 150  Massachusetts Institute of Technology (MIT), USA          BBA
#
#              Specialisation SEMESTER   Domain  \
# 0                   Honours      5th  Finance
# 1        Financial Services      5th  Finance
# 2      Accounting Analytics      5th       BA
# 3                   Honours      5th  Finance
# 4    International Business      3rd       IB
# ..                      ...      ...      ...
# 146      Financial Services      5th  Finance
# 147  International Business      5th  Generic
# 148  International Business      3rd       IB
# 149  International Business      5th       IB
# 150       Digital Marketing      5th       DM
#
#      GENERAL MANAGEMENT SCORE (OUT of 50)  Domain Specific SCORE (OUT 50)  \
# 0                                      50                              50
# 1                                      50                              50
# 2                                      50                              50
# 3                                      49                              50
# 4                                      50                              49
# ..                                    ...                             ...
# 146                                    16                              12
# 147                                    11                              13
# 148                                    16                               8
# 149                                    12                               8
# 150                                     4                               1
#
#      TOTAL SCORE (OUT of 100)  RANK  PERCENTILE
# 0                         100     1    1.000000
# 1                         100     2    0.993377
# 2                         100     3    0.986755
# 3                          99     4    0.980132
# 4                          99     5    0.973510
# ..                        ...   ...         ...
# 146                        28   147    0.033113
# 147                        24   148    0.026490
# 148                        24   149    0.019868
# 149                        20   150    0.013245
# 150                         5   151    0.006623
#
# [151 rows x 12 columns]

# %%
#step3--finding the datatypes and changing them
df2.dtypes
# Out:
# S.No                                      int64
# NAME OF THE STUDENT                      object
# UNIVERSITY                               object
# PROGRAM NAME                             object
# Specialisation                           object
# SEMESTER                                 object
# Domain                                   object
# GENERAL MANAGEMENT SCORE (OUT of 50)      int64
# Domain Specific SCORE (OUT 50)            int64
# TOTAL SCORE (OUT of 100)                  int64
# RANK                                      int64
# PERCENTILE                              float64
# dtype: object

# %%
#step3--changing the datatype of a column
col1=df2["S.No"].astype("float64")
df2["S.No"]=col1
df2
# Out:
#       S.No NAME OF THE STUDENT  \
# 0      0.0         Camila Wood
# 1      1.0  Alexander Thompson
# 2      2.0         Liam Taylor
# 3      3.0      Evelyn Jenkins
# 4      4.0     Michael Jackson
# ..     ...                 ...
# 146  146.0         Avery Lewis
# 147  147.0        Ethan Martin
# 148  148.0  Nicholas Rodriguez
# 149  149.0        Samuel Perez
# 150  150.0           Emily Lee
#
#                                            UNIVERSITY PROGRAM NAME  \
# 0                            Stanford University, USA        B.Com
# 1                            Stanford University, USA        B.Com
# 2                             Harvard University, USA        B.Com
# 3                            Stanford University, USA        B.Com
# 4                             Harvard University, USA          MBA
# ..                                                ...          ...
# 146                          Stanford University, USA          BBA
# 147                          Stanford University, USA          BBA
# 148                           Harvard University, USA          MBA
# 149                          Stanford University, USA          BBA
# 150  Massachusetts Institute of Technology (MIT), USA          BBA
#
#              Specialisation SEMESTER   Domain  \
# 0                   Honours      5th  Finance
# 1        Financial Services      5th  Finance
# 2      Accounting Analytics      5th       BA
# 3                   Honours      5th  Finance
# 4    International Business      3rd       IB
# ..                      ...      ...      ...
# 146      Financial Services      5th  Finance
# 147  International Business      5th  Generic
# 148  International Business      3rd       IB
# 149  International Business      5th       IB
# 150       Digital Marketing      5th       DM
#
#      GENERAL MANAGEMENT SCORE (OUT of 50)  Domain Specific SCORE (OUT 50)  \
# 0                                      50                              50
# 1                                      50                              50
# 2                                      50                              50
# 3                                      49                              50
# 4                                      50                              49
# ..                                    ...                             ...
# 146                                    16                              12
# 147                                    11                              13
# 148                                    16                               8
# 149                                    12                               8
# 150                                     4                               1
#
#      TOTAL SCORE (OUT of 100)  RANK  PERCENTILE
# 0                         100     1    1.000000
# 1                         100     2    0.993377
# 2                         100     3    0.986755
# 3                          99     4    0.980132
# 4                          99     5    0.973510
# ..                        ...   ...         ...
# 146                        28   147    0.033113
# 147                        24   148    0.026490
# 148                        24   149    0.019868
# 149                        20   150    0.013245
# 150                         5   151    0.006623
#
# [151 rows x 12 columns]

# %%
#step4-- sorting values based on the column
df3=df2.sort_values(by="GENERAL MANAGEMENT SCORE (OUT of 50)")
df3
# Out:
#      S.No NAME OF THE STUDENT  \
# 150   150           Emily Lee
# 147   147        Ethan Martin
# 149   149        Samuel Perez
# 137   137     Scarlett Cooper
# 141   141           Aria King
# ..    ...                 ...
# 80     80         Ella Bailey
# 11     11         Carter Hall
# 12     12          Mia Thomas
# 7       7   Olivia Richardson
# 0       0         Camila Wood
#
#                                            UNIVERSITY   PROGRAM NAME  \
# 150  Massachusetts Institute of Technology (MIT), USA            BBA
# 147                          Stanford University, USA            BBA
# 149                          Stanford University, USA            BBA
# 137                          University of Oxford, UK  Intg. BBA+MBA
# 141                       University of Cambridge, UK            BBA
# ..                                                ...            ...
# 80                            Harvard University, USA            MBA
# 11                            Harvard University, USA            MBA
# 12                            Harvard University, USA          B.Com
# 7                            Stanford University, USA            BBA
# 0                            Stanford University, USA          B.Com
#
#                                        Specialisation SEMESTER   Domain  \
# 150                                 Digital Marketing      5th       DM
# 147                            International Business      5th  Generic
# 149                            International Business      5th       IB
# 137                                Business Analytics      9th  Finance
# 141                            International Business      5th  Finance
# ..                                                ...      ...      ...
# 80                             International Business      3rd       IB
# 11                             International Business      3rd       IB
# 12   Information Technology with Accounting Analytics      5th       BA
# 7                              International Business      5th       IB
# 0                                             Honours      5th  Finance
#
#      GENERAL MANAGEMENT SCORE (OUT of 50)  Domain Specific SCORE (OUT 50)  \
# 150                                     4                               1
# 147                                    11                              13
# 149                                    12                               8
# 137                                    15                              19
# 141                                    15                              15
# ..                                    ...                             ...
# 80                                     50                              23
# 11                                     50                              47
# 12                                     50                              47
# 7                                      50                              47
# 0                                      50                              50
#
#      TOTAL SCORE (OUT of 100)  RANK  PERCENTILE
# 150                         5   151    0.006623
# 147                        24   148    0.026490
# 149                        20   150    0.013245
# 137                        34   138    0.092715
# 141                        30   142    0.066225
# ..                        ...   ...         ...
# 80                         73    81    0.470199
# 11                         97    12    0.927152
# 12                         97    13    0.920530
# 7                          97     8    0.953642
# 0                         100     1    1.000000
#
# [151 rows x 12 columns]

# %%
df4=df3.sort_values(by="PERCENTILE")
df4
# Out:
#      S.No NAME OF THE STUDENT  \
# 150   150           Emily Lee
# 149   149        Samuel Perez
# 148   148  Nicholas Rodriguez
# 147   147        Ethan Martin
# 146   146         Avery Lewis
# ..    ...                 ...
# 4       4     Michael Jackson
# 3       3      Evelyn Jenkins
# 2       2         Liam Taylor
# 1       1  Alexander Thompson
# 0       0         Camila Wood
#
#                                            UNIVERSITY PROGRAM NAME  \
# 150  Massachusetts Institute of Technology (MIT), USA          BBA
# 149                          Stanford University, USA          BBA
# 148                           Harvard University, USA          MBA
# 147                          Stanford University, USA          BBA
# 146                          Stanford University, USA          BBA
# ..                                                ...          ...
# 4                             Harvard University, USA          MBA
# 3                            Stanford University, USA        B.Com
# 2                             Harvard University, USA        B.Com
# 1                            Stanford University, USA        B.Com
# 0                            Stanford University, USA        B.Com
#
#              Specialisation SEMESTER   Domain  \
# 150       Digital Marketing      5th       DM
# 149  International Business      5th       IB
# 148  International Business      3rd       IB
# 147  International Business      5th  Generic
# 146      Financial Services      5th  Finance
# ..                      ...      ...      ...
# 4    International Business      3rd       IB
# 3                   Honours      5th  Finance
# 2      Accounting Analytics      5th       BA
# 1        Financial Services      5th  Finance
# 0                   Honours      5th  Finance
#
#      GENERAL MANAGEMENT SCORE (OUT of 50)  Domain Specific SCORE (OUT 50)  \
# 150                                     4                               1
# 149                                    12                               8
# 148                                    16                               8
# 147                                    11                              13
# 146                                    16                              12
# ..                                    ...                             ...
# 4                                      50                              49
# 3                                      49                              50
# 2                                      50                              50
# 1                                      50                              50
# 0                                      50                              50
#
#      TOTAL SCORE (OUT of 100)  RANK  PERCENTILE
# 150                         5   151    0.006623
# 149                        20   150    0.013245
# 148                        24   149    0.019868
# 147                        24   148    0.026490
# 146                        28   147    0.033113
# ..                        ...   ...         ...
# 4                          99     5    0.973510
# 3                          99     4    0.980132
# 2                         100     3    0.986755
# 1                         100     2    0.993377
# 0                         100     1    1.000000
#
# [151 rows x 12 columns]

# %%
#step5--reordering the columns
df4[["NAME OF THE STUDEN|T","UNIVERSITY","RANK"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 #step5--reordering the columns
# ----> 2 df4[["NAME OF THE STUDEN|T","UNIVERSITY","RANK"]]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['NAME OF THE STUDEN|T'] not in index"

# %%
#reordering the rows
a=np.arange(20,51,1)
df4.iloc[a]
# Out:
#       S.No NAME OF THE STUDENT  \
# 130  130.0           Emma Reed
# 129  129.0         Carter Wood
# 128  128.0        Amelia Jones
# 127  127.0          Lily Davis
# 126  126.0         Logan Brown
# 125  125.0          Grace Hall
# 124  124.0       Noah Martinez
# 123  123.0         Emily Moore
# 122  122.0        Ella Stewart
# 121  121.0      Matthew Miller
# 120  120.0      Benjamin Green
# 119  119.0     Charlotte Baker
# 118  118.0     Elijah Williams
# 117  117.0        Sofia Nelson
# 116  116.0           Mia Smith
# 115  115.0       Layla Jackson
# 114  114.0       Sophia Carter
# 113  113.0      Abigail Thomas
# 112  112.0       Joseph Parker
# 111  111.0         Jack Garcia
# 110  110.0       Camila Rivera
# 109  109.0         Liam Taylor
# 108  108.0        Zoey Jenkins
# 107  107.0       Michael Evans
# 106  106.0     Alexander Clark
# 105  105.0       Harper Bailey
# 104  104.0          Ava Walker
# 103  103.0      Gabriel Wilson
# 102  102.0  William Richardson
# 101  101.0     Jackson Johnson
# 100  100.0      Henry Gonzalez
#
#                                             UNIVERSITY   PROGRAM NAME  \
# 130                            Harvard University, USA            MBA
# 129                            Harvard University, USA            MBA
# 128   Massachusetts Institute of Technology (MIT), USA            BBA
# 127                           Stanford University, USA            BBA
# 126                           University of Oxford, UK  Intg. BBA+MBA
# 125                            Harvard University, USA            MBA
# 124                            Harvard University, USA            MBA
# 123                           Stanford University, USA            BBA
# 122                           Stanford University, USA            BBA
# 121                            Harvard University, USA          B.Com
# 120                           Stanford University, USA            BBA
# 119                           Stanford University, USA            BBA
# 118                           Stanford University, USA            BBA
# 117                           Stanford University, USA          B.Com
# 116                           Stanford University, USA            BBA
# 115                            Harvard University, USA            MBA
# 114                            Harvard University, USA            MBA
# 113                           University of Oxford, UK  Intg. BBA+MBA
# 112   Massachusetts Institute of Technology (MIT), USA            BBA
# 111                            Harvard University, USA            MBA
# 110                           University of Oxford, UK  Intg. BBA+MBA
# 109                            Harvard University, USA            MBA
# 108                           Stanford University, USA          B.Com
# 107                           Stanford University, USA          B.Com
# 106                            Harvard University, USA            MBA
# 105                            Harvard University, USA            MBA
# 104                           University of Oxford, UK  Intg. BBA+MBA
# 103                        Imperial College London, UK            BBA
# 102  California Institute of Technology (Caltech), USA            BBA
# 101                            Harvard University, USA          B.Com
# 100                            Harvard University, USA            MBA
#
#                                         Specialisation SEMESTER   Domain  \
# 130                             International Business      3rd       IB
# 129                             International Business      3rd       IB
# 128                                  Digital Marketing      5th       DM
# 127                                 Business Analytics      3rd       IB
# 126                                 Financial Services      9th  Finance
# 125  Innovation Entrepreneurship and Venture Develo...      3rd      E&I
# 124  Innovation Entrepreneurship and Venture Develo...      3rd      E&I
# 123                                            Finance      5th  Finance
# 122                             International Business      5th       IB
# 121   Information Technology with Accounting Analytics      5th       BA
# 120                             International Business      5th       IB
# 119                             International Business      5th       IB
# 118                             International Business      5th       IB
# 117                                 Business Analytics      5th  Generic
# 116                             International Business      5th       IB
# 115                             International Business      3rd       IB
# 114                             International Business      3rd       IB
# 113                                 Financial Services      9th  Finance
# 112                                  Digital Marketing      5th       DM
# 111                             International Business      3rd       IB
# 110                                 Financial Services      9th  Finance
# 109  Innovation Entrepreneurship and Venture Develo...      3rd      E&I
# 108                                 Business Analytics      5th       BA
# 107                                            Finance      5th  Generic
# 106  Innovation Entrepreneurship and Venture Develo...      3rd      E&I
# 105                             International Business      3rd       IB
# 104                                 Financial Services      9th  Finance
# 103                      Entrepreneurship & Innovation      5th      E&I
# 102                                   Brand Management      5th  Generic
# 101            Financial Services with Digital Finance      5th  Finance
# 100                             International Business      3rd       DM
#
#      GENERAL MANAGEMENT SCORE (OUT of 50)  Domain Specific SCORE (OUT 50)  \
# 130                                    21                              21
# 129                                    26                              18
# 128                                    28                              18
# 127                                    33                              14
# 126                                    28                              20
# 125                                    28                              23
# 124                                    19                              34
# 123                                    32                              22
# 122                                    41                              16
# 121                                    24                              33
# 120                                    32                              25
# 119                                    39                              19
# 118                                    26                              32
# 117                                    30                              29
# 116                                    37                              22
# 115                                    28                              33
# 114                                    36                              25
# 113                                    35                              27
# 112                                    32                              30
# 111                                    38                              24
# 110                                    31                              31
# 109                                    37                              25
# 108                                    49                              13
# 107                                    35                              28
# 106                                    28                              36
# 105                                    28                              36
# 104                                    35                              31
# 103                                    33                              33
# 102                                    33                              33
# 101                                    33                              33
# 100                                    36                              31
#
#      TOTAL SCORE (OUT of 100)  RANK  PERCENTILE
# 130                        42   131    0.139073
# 129                        44   130    0.145695
# 128                        46   129    0.152318
# 127                        47   128    0.158940
# 126                        48   127    0.165563
# 125                        51   126    0.172185
# 124                        53   125    0.178808
# 123                        54   124    0.185430
# 122                        57   123    0.192053
# 121                        57   122    0.198675
# 120                        57   121    0.205298
# 119                        58   120    0.211921
# 118                        58   119    0.218543
# 117                        59   118    0.225166
# 116                        59   117    0.231788
# 115                        61   116    0.238411
# 114                        61   115    0.245033
# 113                        62   114    0.251656
# 112                        62   113    0.258278
# 111                        62   112    0.264901
# 110                        62   111    0.271523
# 109                        62   110    0.278146
# 108                        62   109    0.284768
# 107                        63   108    0.291391
# 106                        64   107    0.298013
# 105                        64   106    0.304636
# 104                        66   105    0.311258
# 103                        66   104    0.317881
# 102                        66   103    0.324503
# 101                        66   102    0.331126
# 100                        67   101    0.337748

# %%
#step6--exporting the file back to the file
df4.to_csv("new_data.csv")

# %%
n=int(input("enter the no. of peoples income do u want to enter:"))
l=[]
for i in range(n):
    income=int(input(f"enter the income {i+1}:"))
    l.append(income)
print(l)
bins=[0,10000,25000,50000,100000]
bin_names=['Basic Salary','Minimum Salary','Required Salary','Max Salary']
b=pd.cut(l,bins,labels=bin_names)
b
# Out:
# enter the no. of peoples income do u want to enter: 4
# enter the income 1: 12000
# enter the income 2: 120000
# enter the income 3: 87000
# enter the income 4: 90000
# [12000, 120000, 87000, 90000]
# ['Minimum Salary', NaN, 'Max Salary', 'Max Salary']
# Categories (4, object): ['Basic Salary' < 'Minimum Salary' < 'Required Salary' < 'Max Salary']

# %%
n=int(input("enter the no. of peoples age do u want to enter:"))
l1=[]
for i in range(n):
    age=int(input(f"enter the age of person {i+1}:"))
    l1.append(age)
print(l1)
bins=[0,13,19,27,60,100]
bin_names=['Child age','Teenage','Adult age','middle age','old age']
b=pd.cut(l1,bins,labels=bin_names)
b
# Out:
# enter the no. of peoples age do u want to enter: 4
# enter the age of person 1: 12
# enter the age of person 2: 34
# enter the age of person 3: 78
# enter the age of person 4: 65
# [12, 34, 78, 65]
# ['Child age', 'middle age', 'old age', 'old age']
# Categories (5, object): ['Child age' < 'Teenage' < 'Adult age' < 'middle age' < 'old age']
