# %%
import matplotlib.pyplot as plt

# %%
height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
plt.plot(weight,height,color='g',marker='*',markersize=10,ls='dashed',linewidth=2)

plt.xlabel("Weight in kg")
plt.ylabel("Height in cm")
plt.title('Average weight with respect to average height')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 3
#       1 height=[121.9,124.5,129.5,134.6,139.7,147.3,152.4,157.5,162.6]
#       2 weight=[19.7,21.3,23.5,25.9,28.5,32.1,35.7,39.6,43.2]
# ----> 3 plt.plot(weight,height,color='g',marker='*',markersize=10,ls='dashed',linewidth=2,ylabel="ji")
#       5 plt.xlabel("Weight in kg")
#       6 plt.ylabel("Height in cm")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
# ...

# %%
import pandas as pd

# %%
df1=pd.read_csv("MelaSales.csv")
print(df1)
# Out:
#    Week1  Week2  Week3        Day
# 0   5000   4000   4000     Monday
# 1   5900   3000   5800    Tuesday
# 2   6500   5000   3500  Wednesday
# 3   3500   5500   2500   Thursday
# 4   4000   3000   3000     Friday
# 5   5300   4300   5300   Saturday
# 6   7900   5900   6000     Sunday

# %%
x=df1.Day
y1=df1.Week1
y2=df1.Week2
y3=df1.Week3
df1.plot(x="Day",color=['r','b','brown'])
plt.title("Mela Sales Report")
plt.xlabel("Days")
plt.ylabel("Sales in Rs.")
# Out:
# Text(0, 0.5, 'Sales in Rs.')

# %%
df1.plot(kind='bar',x="Day",color=['r','g','b'],xlabel='days',ylabel='Sales in Rs.')
# Out:
# <Axes: xlabel='days', ylabel='Sales in Rs.'>
